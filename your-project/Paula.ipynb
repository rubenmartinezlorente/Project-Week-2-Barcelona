# %% [markdown]
# Questions on Immigration

# %%
import pandas as pd

# %% [markdown]
# What is the most frequent nationality?
# Is there more male or female immigrants?
# Are they young or old? How much is the difference between these range? (define age ranges before)
# Do immigrants live in neighbourhoods where mean rent is lower?
# Do immigrants of the same nationality settle close to one another?

# %%
##files to import

by_nationality = pd.read_csv("/Users/p/Documents/Ironhack/Projects/Project-Week-2-Barcelona/datasets/3.-Population/immigrants-by-nationality.csv")
population=pd.read_csv("/Users/p/Documents/Ironhack/Projects/Project-Week-2-Barcelona/datasets/3.-Population/population.csv")

# %%
by_nationality

# %%
population

# %%
## I want to calculate the percentage of the population that are foreigners, so I created the variables for the population of each year

population_tot=population.groupby(['Year']).sum().loc[:,'Number']
population_2017=population_tot[2017]
population_2016=population_tot[2016]
population_2015=population_tot[2015]

population_2015
population_2016
population_2017
# Out:
# numpy.int64

# %%
by_nationality.dtypes # checked what data types exist in the dataframe

# %%
""""
This dataframe includes Spanish people from outside Barcelona as immigrants in Barcelona.
So, I created a dataframe for all immigrants that are not from Spain because they are qualitatively different in 
terms of rights, access to public services and other relevant stuff
"""
# Out:
# '"\nThis dataframe includes Spanish people from outside Barcelona as immigrants in Barcelona.\nSo, I created a dataframe for all immigrants that are not from Spain because they are qualitatively different in \nterms of rights, access to public services and other relevant stuff\n'

# %%
foreigners = by_nationality.loc[(by_nationality.Nationality != "Spain")]

# %%
foreigners
# Out:
#        Year  District Code        District Name  Neighborhood Code  \
# 74     2017              1         Ciutat Vella                  1
# 75     2017              1         Ciutat Vella                  2
# 76     2017              1         Ciutat Vella                  3
# 77     2017              1         Ciutat Vella                  4
# 78     2017              2             Eixample                  5
# 79     2017              2             Eixample                  6
# 80     2017              2             Eixample                  7
# 81     2017              2             Eixample                  8
# 82     2017              2             Eixample                  9
# 83     2017              2             Eixample                 10
# 84     2017              3       Sants-Montjuïc                 11
# 85     2017              3       Sants-Montjuïc                 12
# 86     2017              3       Sants-Montjuïc                 13
# 87     2017              3       Sants-Montjuïc                 14
# 88     2017              3       Sants-Montjuïc                 15
# 89     2017              3       Sants-Montjuïc                 16
# 90     2017              3       Sants-Montjuïc                 17
# 91     2017              3       Sants-Montjuïc                 18
# 92     2017              4            Les Corts                 19
# 93     2017              4            Les Corts                 20
# 94     2017              4            Les Corts                 21
# 95     2017              5  Sarrià-Sant Gervasi                 22
# 96     2017              5  Sarrià-Sant Gervasi                 23
# 97     2017              5  Sarrià-Sant Gervasi                 24
# 98     2017              5  Sarrià-Sant Gervasi                 25
# 99     2017              5  Sarrià-Sant Gervasi                 26
# 100    2017              5  Sarrià-Sant Gervasi                 27
# 101    2017              6               Gràcia                 28
# 102    2017              6               Gràcia                 29
# 103    2017              6               Gràcia                 30
# ...     ...            ...                  ...                ...
# 35194  2015              8           Nou Barris                 45
# 35195  2015              8           Nou Barris                 46
# 35196  2015              8           Nou Barris                 47
# 35197  2015              8           Nou Barris                 48
# 35198  2015              8           Nou Barris                 49
# 35199  2015              8           Nou Barris                 50
# 35200  2015              8           Nou Barris                 51
# 35201  2015              8           Nou Barris                 52
# 35202  2015              8           Nou Barris                 53
# 35203  2015              8           Nou Barris                 54
# 35204  2015              8           Nou Barris                 55
# 35205  2015              8           Nou Barris                 56
# 35206  2015              9          Sant Andreu                 57
# 35207  2015              9          Sant Andreu                 58
# 35208  2015              9          Sant Andreu                 59
# 35209  2015              9          Sant Andreu                 60
# 35210  2015              9          Sant Andreu                 61
# 35211  2015              9          Sant Andreu                 62
# 35212  2015              9          Sant Andreu                 63
# 35213  2015             10           Sant Martí                 64
# 35214  2015             10           Sant Martí                 65
# 35215  2015             10           Sant Martí                 66
# 35216  2015             10           Sant Martí                 67
# 35217  2015             10           Sant Martí                 68
# 35218  2015             10           Sant Martí                 69
# 35219  2015             10           Sant Martí                 70
# 35220  2015             10           Sant Martí                 71
# 35221  2015             10           Sant Martí                 72
# 35222  2015             10           Sant Martí                 73
# 35223  2015             99            No consta                 99
#
#                                   Neighborhood Name     Nationality  Number
# 74                                         el Raval           Italy     360
# 75                                   el Barri Gòtic           Italy     275
# 76                                   la Barceloneta           Italy     285
# 77            Sant Pere, Santa Caterina i la Ribera           Italy     355
# 78                                    el Fort Pienc           Italy     207
# 79                               la Sagrada Família           Italy     295
# 80                           la Dreta de l'Eixample           Italy     284
# 81                  l'Antiga Esquerra de l'Eixample           Italy     280
# 82                   la Nova Esquerra de l'Eixample           Italy     314
# 83                                      Sant Antoni           Italy     188
# 84                                     el Poble Sec           Italy     270
# 85                       la Marina del Prat Vermell           Italy       0
# 86                                la Marina de Port           Italy      45
# 87                            la Font de la Guatlla           Italy      42
# 88                                      Hostafrancs           Italy      72
# 89                                       la Bordeta           Italy      44
# 90                                    Sants - Badal           Italy      56
# 91                                            Sants           Italy     155
# 92                                        les Corts           Italy     130
# 93                       la Maternitat i Sant Ramon           Italy      52
# 94                                        Pedralbes           Italy      23
# 95            Vallvidrera, el Tibidabo i les Planes           Italy      12
# 96                                           Sarrià           Italy      77
# 97                                  les Tres Torres           Italy      26
# 98                       Sant Gervasi - la Bonanova           Italy      49
# 99                           Sant Gervasi - Galvany           Italy     135
# 100                            el Putxet i el Farró           Italy      97
# 101                       Vallcarca i els Penitents           Italy      42
# 102                                         el Coll           Italy      27
# 103                                        la Salut           Italy      50
# ...                                             ...             ...     ...
# 35194                                         Porta  No information       0
# 35195                           el Turó de la Peira  No information       0
# 35196                                   Can Peguera  No information       0
# 35197                                  la Guineueta  No information       0
# 35198                                     Canyelles  No information       0
# 35199                                  les Roquetes  No information       0
# 35200                                        Verdun  No information       0
# 35201                                la Prosperitat  No information       0
# 35202                              la Trinitat Nova  No information       0
# 35203                                    Torre Baró  No information       0
# 35204                              Ciutat Meridiana  No information       0
# 35205                                      Vallbona  No information       0
# 35206                             la Trinitat Vella  No information       0
# 35207                                 Baró de Viver  No information       0
# 35208                                 el Bon Pastor  No information       0
# 35209                                   Sant Andreu  No information       1
# 35210                                    la Sagrera  No information       1
# 35211                      el Congrés i els Indians  No information       0
# 35212                                         Navas  No information       0
# 35213                    el Camp de l'Arpa del Clot  No information       0
# 35214                                       el Clot  No information       1
# 35215             el Parc i la Llacuna del Poblenou  No information       2
# 35216                 la Vila Olímpica del Poblenou  No information       1
# 35217                                   el Poblenou  No information       1
# 35218  Diagonal Mar i el Front Marítim del Poblenou  No information       0
# 35219                         el Besòs i el Maresme  No information       0
# 35220                       Provençals del Poblenou  No information       0
# 35221                      Sant Martí de Provençals  No information       0
# 35222                           la Verneda i la Pau  No information       1
# 35223                                     No consta  No information       0
#
# [35002 rows x 7 columns]

# %%
by_nationality=by_nationality.rename(columns={'Neighborhood Name':'Neighborhood_Name',
                               'District Name':'District_Name',
                               'District Code':'District_Code',
                               'Neighborhood Code':'Neighborhood_Code'
                              }) ## I renamed some of the headers so they didn't have a whitespace

# %%
by_nationality.Year.unique() # checked which were the possible years

# %%
by_nationality.District_Name.unique() # checked which were the possible Districts

# %%
by_nationality.Neighborhood_Name.unique() # checked which were the possible Neighborhoods

# %%
by_nationality.Nationality.unique() # checked which were the possible nationalities

# %% [markdown]
# What is the total number of immigrants by year?

# %%
by_nationality.groupby('Year').sum()['Number']
# Out:
# Year
# 2015    88982
# 2016    85172
# 2017    97327
# Name: Number, dtype: int64

# %%
"""
I created a variable with the value for each year to calculate percentage 
of immigrants over total population per year

"""

# %%
foreigners_tot=foreigners.groupby(['Year']).sum().loc[:,'Number']
foreigners_2017=foreigners_tot[2017]
foreigners_2016=foreigners_tot[2016]
foreigners_2015=foreigners_tot[2015]
# Out:
# 52122

# %%
foreigners_2017_perc=(foreigners_2017/population_2017)*100
foreigners_2016_perc=(foreigners_2016/population_2016)*100
foreigners_2015_perc=(foreigners_2015/population_2015)*100

# %% [markdown]
# What is the most frequent nationality of immigrants in Barcelona?

# %%
freq_nationalities=pd.DataFrame(by_nationality.groupby(['Year','Nationality']).sum().loc[:,'Number'])

# %%
freq_nationalities_f=pd.DataFrame(foreigners.groupby(['Year','Nationality']).sum().loc[:,'Number'])

# %%
freq_nationalities_f=pd.DataFrame(foreigners.loc[(foreigners.Year == 2015)].groupby(['Nationality']).sum().loc[:,'Number'])
freq_nationalities_f.sort_values('Number', ascending =False)
# Out:
#                           Number
# Nationality
# Italy                       4811
# Pakistan                    3708
# China                       3091
# France                      2176
# Colombia                    1971
# Morocco                     1934
# Honduras                    1880
# Venezuela                   1571
# Peru                        1416
# Brasil                      1410
# India                       1371
# Ecuador                     1335
# Russia                      1322
# Argentina                   1208
# Bolivia                     1147
# United States               1128
# Mexico                      1119
# Dominican Republic          1117
# United Kingdom              1112
# Romania                     1074
# Ukraine                     1033
# Germany                      980
# Philippines                  769
# Chile                        754
# Portugal                     741
# Paraguay                     609
# Bangladesh                   593
# Netherlands                  491
# Georgia                      485
# Poland                       421
# ...                          ...
# Uganda                         3
# Benin                          3
# Yemen                          3
# Dominica                       3
# Ethiopia                       3
# Sudan                          3
# Qatar                          3
# Somalia                        3
# Madagascar                     3
# Jamaica                        3
# Gabon                          2
# Central African Republic       2
# Mauritius                      2
# Rwanda                         2
# Cape Verde                     2
# Seychelles                     1
# Trinidad and Tobago            1
# Sierra Leone                   1
# Namibia                        1
# Taiwan                         1
# Saint Kitts and Nevis          1
# Cambodja                       1
# Burundi                        1
# Djibouti                       1
# Maldives                       1
# Barbados                       1
# Bahrain                        1
# Grenada                        1
# Swaziland                      1
# Oman                           1
#
# [153 rows x 1 columns]

# %%
freq_nationalities_f.order
# Out:
#                                Number
# Year Nationality
# 2015 Afghanistan                   20
#      Albania                       63
#      Algeria                      292
#      Andorra                       71
#      Angola                        10
#      Argentina                   1208
#      Armenia                      243
#      Australia                     82
#      Austria                      116
#      Azerbaijan                    46
#      Bahrain                        1
#      Bangladesh                   593
#      Barbados                       1
#      Belarus                       74
#      Belgium                      277
#      Benin                          3
#      Bolivia                     1147
#      Bosnia and Herzegovina        17
#      Brasil                      1410
#      Bulgaria                     282
#      Burkina Faso                   4
#      Burundi                        1
#      Cambodja                       1
#      Camerun                       42
#      Canada                       175
#      Cape Verde                     2
#      Central African Republic       2
#      Chile                        754
#      China                       3091
#      Colombia                    1971
# ...                               ...
# 2017 Somalia                        2
#      South Africa                  44
#      South Korea                  230
#      Sri Lanka                      5
#      State of Palestine            31
#      Sudan                         14
#      Sweden                       302
#      Switzerland                  194
#      Syria                        115
#      São Tomé and Príncipe          1
#      Tanzania                      13
#      Thailand                      23
#      The Bahamas                    2
#      Togo                           4
#      Trinidad and Tobago            6
#      Tunisia                       72
#      Turkey                       446
#      Turkmenistan                   4
#      Uganda                         7
#      Ukraine                      894
#      United Arab Emirates           4
#      United Kingdom              1459
#      United States               1507
#      Uruguay                      329
#      Uzbekistan                    30
#      Venezuela                   3021
#      Vietnam                      107
#      Yemen                          2
#      Zambia                         2
#      Zimbabwe                       3
#
# [473 rows x 1 columns]

# %%
freq_nationalities_f.sort_values('Number', ascending=False)
# Out:
#                             Number
# Year Nationality
# 2017 Italy                    6309
# 2016 Italy                    4973
# 2015 Italy                    4811
#      Pakistan                 3708
# 2017 China                    3299
#      Colombia                 3255
# 2015 China                    3091
# 2016 Pakistan                 3032
# 2017 Venezuela                3021
#      Pakistan                 2967
# 2016 China                    2959
# 2017 Honduras                 2767
#      France                   2670
# 2016 Colombia                 2551
# 2017 Peru                     2473
# 2016 France                   2263
# 2015 France                   2176
# 2016 Honduras                 2087
#      Venezuela                2050
# 2015 Colombia                 1971
#      Morocco                  1934
# 2017 Morocco                  1931
#      Argentina                1885
# 2015 Honduras                 1880
# 2017 Brasil                   1757
# 2016 Morocco                  1709
#      Peru                     1609
# 2015 Venezuela                1571
# 2016 Brasil                   1512
# 2017 United States            1507
# ...                            ...
# 2016 São Tomé and Príncipe       1
# 2015 Barbados                    1
#      Bahrain                     1
# 2016 Tajikistan                  1
#      North Korea                 1
# 2017 Cape Verde                  1
#      Bahrain                     1
# 2015 Grenada                     1
#      Seychelles                  1
#      Saint Kitts and Nevis       1
#      Swaziland                   1
# 2017 Laos                        1
# 2015 Taiwan                      1
# 2016 Togo                        1
# 2015 Oman                        1
#      Trinidad and Tobago         1
#      Namibia                     1
# 2016 Barbados                    1
# 2017 Oman                        1
#      Grenada                     1
# 2015 Maldives                    1
# 2016 East Timor                  1
#      Guyana                      1
#      Lesotho                     1
#      Liberia                     1
#      Maldives                    1
# 2015 Sierra Leone                1
# 2017 Barbados                    1
#      Solomon Islands             1
# 2016 The Bahamas                 1
#
# [473 rows x 1 columns]

# %%
pd.DataFrame(by_nationality.groupby(['District_Name','Nationality']).sum().loc['Ciutat Vella', 'Number']).sort_values('Number', ascending=False)

# %%
by_nationality.Nationality.value_counts()

# %%
by_nationality.groupby("Year").sum()

# %%
#by_nationality.groupby(["Year","District_Name"]).sum() ## if you reverse the order you get the inverse order of columns
by_nationality.groupby(["District_Name","Year"]).mean()
by_nationality.groupby(["District_Name","Year"]).mean().loc[("Ciutat Vella",2015)]

# %% [markdown]
# Do immigrants of the same nationality settle in the same Districts?

# %%
foreigners.head()
# Out:
#     Year  District Code District Name  Neighborhood Code  \
# 74  2017              1  Ciutat Vella                  1
# 75  2017              1  Ciutat Vella                  2
# 76  2017              1  Ciutat Vella                  3
# 77  2017              1  Ciutat Vella                  4
# 78  2017              2      Eixample                  5
#
#                         Neighborhood Name Nationality  Number
# 74                               el Raval       Italy     360
# 75                         el Barri Gòtic       Italy     275
# 76                         la Barceloneta       Italy     285
# 77  Sant Pere, Santa Caterina i la Ribera       Italy     355
# 78                          el Fort Pienc       Italy     207

# %%
foreigners.groupby(["District Name","Year"]).sum()
# Out:
#                           District Code  Neighborhood Code  Number
# District Name       Year
# Ciutat Vella        2015            612               1530    8818
#                     2016            648               1620    8686
#                     2017            632               1580   10069
# Eixample            2015           1836               6885   10124
#                     2016           1944               7290   10622
#                     2017           1896               7110   12487
# Gràcia              2015           4590              22950    3642
#                     2016           4860              24300    3559
#                     2017           4740              23700    4310
# Horta-Guinardó      2015          11781              63954    3349
#                     2016          12474              67716    3699
#                     2017          12166              66044    4544
# Les Corts           2015           1836               9180    1999
#                     2016           1944               9720    2031
#                     2017           1896               9480    2420
# No consta           2015          15147              15147       3
#                     2016          16038              16038       2
#                     2017          15642              15642       0
# Nou Barris          2015          15912              99450    3955
#                     2016          16848             105300    4308
#                     2017          16432             102700    5261
# Sant Andreu         2015           9639              64260    2891
#                     2016          10206              68040    2997
#                     2017           9954              66360    3622
# Sant Martí          2015          15300             104805    6468
#                     2016          16200             110970    6718
#                     2017          15800             108230    7994
# Sants-Montjuïc      2015           3672              17748    6432
#                     2016           3888              18792    6192
#                     2017           3792              18328    7464
# Sarrià-Sant Gervasi 2015           4590              22491    3275
#                     2016           4860              23814    3308
#                     2017           4740              23226    3802
