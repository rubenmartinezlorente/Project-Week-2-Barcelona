# %%
import pandas as pd

# %%
##files to import

immi_emmi_by_sex= pd.read_csv("/Users/p/Documents/Ironhack/Projects/Project-Week-2-Barcelona/datasets/3.-Population/immigrants-emigrants-by-sex.csv")

# %%
emigrants_by_sex
# Out:
#      Year  District Code        District Name  Neighborhood Code  \
# 0    2017              1         Ciutat Vella                  1
# 1    2017              1         Ciutat Vella                  2
# 2    2017              1         Ciutat Vella                  3
# 3    2017              1         Ciutat Vella                  4
# 4    2017              2             Eixample                  5
# 5    2017              2             Eixample                  6
# 6    2017              2             Eixample                  7
# 7    2017              2             Eixample                  8
# 8    2017              2             Eixample                  9
# 9    2017              2             Eixample                 10
# 10   2017              3       Sants-Montjuïc                 11
# 11   2017              3       Sants-Montjuïc                 12
# 12   2017              3       Sants-Montjuïc                 13
# ...
